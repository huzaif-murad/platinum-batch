# %% [markdown]
# #### Radix Sort

# %%
lst = [78,23,45,38,29,58,26,11,27,38]

largest = max(lst)
place = 1

while place <= largest:
    bucket = [[] for _ in range(10)]
    for i in lst:
        key = (i //place) % 10

        bucket[key].append(i)  
    lst = []
    index=0      
    for i in bucket:
        lst[0]
    place *= 10

print(lst)
